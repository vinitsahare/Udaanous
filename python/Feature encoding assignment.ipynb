# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder

# %%
data = pd.read_csv("C:/Users/Chet/Documents/practice_data2.csv")

# %%
data.head()
# Out:
#    EmployeeID  gender       department  Days Present Accuracy_of_Work  \
# 0           1    Male            Sales            20             High
# 1           2  Female        Marketing            22           Medium
# 2           3    Male  Human Resources            25             High
# 3           4    Male      Engineering            19              Low
# 4           5  Female          Finance            23           Medium
#
#   Meeting Project Deadlines  Task Completion Rates  \
# 0                       Yes                     85
# 1                       Yes                     90
# 2                        No                     80
# 3                       Yes                     75
# 4                       Yes                     85
#
#    Interpersonal Skills Rating  Decision-Making Skills Rating  \
# 0                            8                              7
# 1                            7                              6
# ...

# %% [markdown]
# ##  The first value of the gender column after performing the label encoding?

# %%
encoder = LabelEncoder()
data['gender'] = encoder.fit_transform(data['gender'])

print(data.head())
# Out:
#    EmployeeID  gender       department  Days Present Accuracy_of_Work  \
# 0           1       1            Sales            20             High
# 1           2       0        Marketing            22           Medium
# 2           3       1  Human Resources            25             High
# 3           4       1      Engineering            19              Low
# 4           5       0          Finance            23           Medium
#
#   Meeting Project Deadlines  Task Completion Rates  \
# 0                       Yes                     85
# 1                       Yes                     90
# 2                        No                     80
# 3                       Yes                     75
# 4                       Yes                     85
#
#    Interpersonal Skills Rating  Decision-Making Skills Rating  \
# 0                            8                              7
# 1                            7                              6
# ...

# %% [markdown]
# ## selecting Feature

# %%
import pandas as pd

# %%
data2 = pd.read_csv("C:/Users/Chet/Documents/practice_data2.csv")

# %%
data2.head()
# Out:
#    EmployeeID  gender       department  Days Present Accuracy_of_Work  \
# 0           1    Male            Sales            20             High
# 1           2  Female        Marketing            22           Medium
# 2           3    Male  Human Resources            25             High
# 3           4    Male      Engineering            19              Low
# 4           5  Female          Finance            23           Medium
#
#   Meeting Project Deadlines  Task Completion Rates  \
# 0                       Yes                     85
# 1                       Yes                     90
# 2                        No                     80
# 3                       Yes                     75
# 4                       Yes                     85
#
#    Interpersonal Skills Rating  Decision-Making Skills Rating  \
# 0                            8                              7
# 1                            7                              6
# ...

# %%
x = data2.drop(['EmployeeID'], axis=1)
x
# Out:
#     gender       department  Days Present Accuracy_of_Work  \
# 0     Male            Sales            20             High
# 1   Female        Marketing            22           Medium
# 2     Male  Human Resources            25             High
# 3     Male      Engineering            19              Low
# 4   Female          Finance            23           Medium
# 5     Male            Sales            21             High
# 6   Female        Marketing            24              Low
# 7     Male  Human Resources            18           Medium
# 8     Male      Engineering            20             High
# 9   Female          Finance            22           Medium
# 10    Male            Sales            25             High
# 11  Female        Marketing            19              Low
# 12    Male  Human Resources            23           Medium
# 13    Male      Engineering            21             High
# 14  Female          Finance            24              Low
# ...

# %% [markdown]
# ##  StandardScaler

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

scaled = scaler.fit_transform(features)
scaled_features = pd.DataFrame(scaled, columns=features.columns)
scaled_features
# Out:
#    Days Present  Task Completion Rates  Interpersonal Skills Rating  \
# 0     -0.842927               0.392232                     0.588348
# 1      0.093659               1.372813                    -0.392232
# 2      1.498537              -0.588348                     1.568929
# 3     -1.311220              -1.568929                    -1.372813
# 4      0.561951               0.392232                    -0.392232
#
#    Decision-Making Skills Rating  Sales Revenue Generated
# 0                       0.392232                -1.527547
# 1                      -0.588348                 0.944079
# 2                       1.372813                 0.812570
# 3                      -1.568929                 0.623285
# 4                       0.392232                -0.852387

# %% [markdown]
# ##  MinMaxScaler

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

scaled = scaler.fit_transform(features)
scaled_features = pd.DataFrame(scaled, columns=features.columns)
print(scaled_features)
# Out:
#    Days Present  Task Completion Rates  Interpersonal Skills Rating  \
# 0      0.166667               0.666667                     0.666667
# 1      0.500000               1.000000                     0.333333
# 2      1.000000               0.333333                     1.000000
# 3      0.000000               0.000000                     0.000000
# 4      0.666667               0.666667                     0.333333
#
#    Decision-Making Skills Rating  Sales Revenue Generated
# 0                       0.666667                 0.000000
# 1                       0.333333                 1.000000
# 2                       1.000000                 0.946793
# 3                       0.000000                 0.870209
# 4                       0.666667                 0.273164

# %% [markdown]
# ## PCA

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# %%
scaler = StandardScaler()
scaled_features = scaler.fit_transform(features)


pca = PCA()
temp_pca = pca.fit_transform(scaled_features)

evr = pca.explained_variance_ratio_
plt.figure(figsize=(10,6))
plt.plot(range(1, len(evr) + 1), evr, marker='o')
plt.title('Explained Variance Ratio by Number of Components')
plt.xlabel('Number of Components')
plt.ylabel('Explained Variance Ratio')
plt.show()


num_components = 3


pca = PCA(n_components=num_components)
x_pca = pca.fit_transform(scaled_features)

print(f"PCA result shape: {x_pca.shape}")
print("First few rows of PCA-transformed data:")
print(x_pca[:5])
# Out:
# PCA result shape: (5, 3)
# First few rows of PCA-transformed data:
# [[ 0.32562978 -1.71957911 -0.6300218 ]
#  [-0.29681413  0.21836233  1.7535127 ]
#  [ 2.29620336  1.41366347 -0.56006702]
#  [-2.78420422  0.82059304 -0.69999762]
#  [ 0.45918521 -0.73303973  0.13657375]]

# %% [markdown]
# ## train_test_split

# %%
from sklearn.model_selection import train_test_split

# %%
scaler = StandardScaler()
scaled = scaler.fit_transform(features)

x_train, x_test, y_train, y_test = train_test_split(scaled, y, test_size=0.2, random_state=42)

print("Training features (x_train):\n", x_train)
print("\nTraining labels (y_train):\n", y_train)
print("\nTest features (x_test):\n", x_test)
print("\nTest labels (y_test):\n", y_test)
# Out:
# Training features (x_train):
#  [[ 0.56195149  0.39223227 -0.39223227  0.39223227 -0.85238651]
#  [ 1.4985373  -0.58834841  1.56892908  1.37281295  0.81256977]
#  [-0.84292723  0.39223227  0.58834841  0.39223227 -1.52754678]
#  [-1.31122014 -1.56892908 -1.37281295 -1.56892908  0.62328501]]
#
# Training labels (y_train):
#  4    Yes
# 2     No
# 0     No
# 3     No
# Name: churned, dtype: object
#
# Test features (x_test):
#  [[ 0.09365858  1.37281295 -0.39223227 -0.58834841  0.94407851]]
#
# Test labels (y_test):
#  1    Yes
# Name: churned, dtype: object
