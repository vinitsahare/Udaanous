# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("D:\DATA ANALYTICS\my sql\datasets\Messy data set.csv")
data.head()
print(data)
# Out:
#      ID     Name         Age               Email    JoinDate    Salary
# 0     1    Alice          25   alice@example.com  01-01-2020     50000
# 1     2      Bob          30     bob@example.com  not a date     60000
# 2     2      Bob          30     bob@example.com  01-02-2020     60000
# 3     4  Charlie         NaN            charlie@  01-03-2020     70000
# 4     5    David  Twenty-two                 NaN  01-04-2020       NaN
# 5     6      Eve          45         eve@example  01-05-2020     90000
# 6     7    Frank          50  frank@@example.com  01-06-2020    100000
# 7     8    Grace          55   grace@example.com  01-07-2020  one lakh
# 8  nine    Heidi          60   heidi@example.com  2020.08.01    120000
# 9    10      NaN          65      10@example.com  01-09-2020    130000
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\Dell\AppData\Local\Temp\ipykernel_5524\2181509368.py:1: SyntaxWarning: invalid escape sequence '\D'
#   data = pd.read_csv("D:\DATA ANALYTICS\my sql\datasets\Messy data set.csv")

# %%
missing_data = data.isnull().sum()
missing_data
# Out:
# ID          0
# Name        1
# Age         1
# Email       1
# JoinDate    0
# Salary      1
# dtype: int64

# %%
from sklearn.impute import SimpleImputer

# %%
imputer = SimpleImputer(strategy = 'most_frequent')
imputer.fit(data[['Name']])
data[['Name']] = imputer.transform(data[['Name']])

# %%
imputer = SimpleImputer(strategy = 'mean')
imputer.fit(data[['Age']])
data[['Age']] = imputer.transform(data[['Age']])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 2
#       1 imputer = SimpleImputer(strategy = 'mean')
# ----> 2 imputer.fit(data[['Age']])
#       3 data[['Age']] = imputer.transform(data[['Age']])
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\sklearn\impute\_base.py:421, in SimpleImputer.fit(self, X, y)
#     403 @_fit_context(prefer_skip_nested_validation=True)
#     404 def fit(self, X, y=None):
#     405     """Fit the imputer on `X`.
#     406
#     407     Parameters
#    (...)
#     419         Fitted estimator.
#     420     """
# --> 421     X = self._validate_input(X, in_fit=True)
#     423     # default fill_value is 0 for numerical input and "missing_value"
#     424     # otherwise
#     425     if self.fill_value is None:
#
# File ~\anaconda3\Lib\site-packages\sklearn\impute\_base.py:348, in SimpleImputer._validate_input(self, X, in_fit)
#     342 if "could not convert" in str(ve):
#     343     new_ve = ValueError(
#     344         "Cannot use {} strategy with non-numeric data:\n{}".format(
#     345             self.strategy, ve
#     346         )
#     347     )
# --> 348     raise new_ve from None
#     349 else:
#     350     raise ve
#
# ValueError: Cannot use mean strategy with non-numeric data:
# could not convert string to float: 'Twenty-two'

# %%
data.dtypes

# %%
data['Age'] = pd.to_numeric(data['Age'], errors='coerce')

# %%
data['ID'] = pd.to_numeric(data['ID'], errors='coerce')

# %%
data['JoinDate'] = pd.to_datetime(data['JoinDate'], errors='coerce')

# %%
data['Salary'] = pd.to_numeric(data['Salary'], errors='coerce')

# %%
imputer = SimpleImputer(strategy = 'most_frequent')
imputer.fit(data[['Email']])
data[['Email']] = imputer.transform(data[['Email']])

# %%
data.dtypes
# Out:
# ID          object
# Name        object
# Age         object
# Email       object
# JoinDate    object
# Salary      object
# dtype: object

# %%
data
# Out:
#      ID     Name         Age               Email    JoinDate    Salary
# 0     1    Alice          25   alice@example.com  01-01-2020     50000
# 1     2      Bob          30     bob@example.com  not a date     60000
# 2     2      Bob          30     bob@example.com  01-02-2020     60000
# 3     4  Charlie         NaN            charlie@  01-03-2020     70000
# 4     5    David  Twenty-two                 NaN  01-04-2020       NaN
# 5     6      Eve          45         eve@example  01-05-2020     90000
# 6     7    Frank          50  frank@@example.com  01-06-2020    100000
# 7     8    Grace          55   grace@example.com  01-07-2020  one lakh
# 8  nine    Heidi          60   heidi@example.com  2020.08.01    120000
# 9    10      Bob          65      10@example.com  01-09-2020    130000

# %%
data.loc[data['Email'] == 'charlie@', 'Email'] = 'charlie@example.com'

# %%
data
# Out:
#      ID     Name         Age                Email    JoinDate    Salary
# 0     1    Alice          25    alice@example.com  01-01-2020     50000
# 1     2      Bob          30      bob@example.com  not a date     60000
# 2     2      Bob          30      bob@example.com  01-02-2020     60000
# 3     4  Charlie         NaN  charlie@example.com  01-03-2020     70000
# 4     5    David  Twenty-two                  NaN  01-04-2020       NaN
# 5     6      Eve          45          eve@example  01-05-2020     90000
# 6     7    Frank          50   frank@@example.com  01-06-2020    100000
# 7     8    Grace          55    grace@example.com  01-07-2020  one lakh
# 8  nine    Heidi          60    heidi@example.com  2020.08.01    120000
# 9    10      Bob          65       10@example.com  01-09-2020    130000

# %%
data.loc[data['Salary'] == 'one lakh' , 'Salary'] = 100000

# %%
data
# Out:
#      ID     Name         Age                Email    JoinDate  Salary
# 0     1    Alice          25    alice@example.com  01-01-2020   50000
# 1     2      Bob          30      bob@example.com  not a date   60000
# 2     2      Bob          30      bob@example.com  01-02-2020   60000
# 3     4  Charlie         NaN  charlie@example.com  01-03-2020   70000
# 4     5    David  Twenty-two                  NaN  01-04-2020     NaN
# 5     6      Eve          45          eve@example  01-05-2020   90000
# 6     7    Frank          50   frank@@example.com  01-06-2020  100000
# 7     8    Grace          55    grace@example.com  01-07-2020  100000
# 8  nine    Heidi          60    heidi@example.com  2020.08.01  120000
# 9    10      Bob          65       10@example.com  01-09-2020  130000

# %%
imputer = SimpleImputer(strategy = 'mean')
imputer.fit(data[['Salary']])
data[['Salary']] = imputer.transform(data[['Salary']])

# %%
data['Salary']= data['Salary'].astype(int)

# %%
data
# Out:
#      ID     Name         Age                Email    JoinDate  Salary
# 0     1    Alice          25    alice@example.com  01-01-2020   50000
# 1     2      Bob          30      bob@example.com  not a date   60000
# 2     2      Bob          30      bob@example.com  01-02-2020   60000
# 3     4  Charlie         NaN  charlie@example.com  01-03-2020   70000
# 4     5    David  Twenty-two                  NaN  01-04-2020   86666
# 5     6      Eve          45          eve@example  01-05-2020   90000
# 6     7    Frank          50   frank@@example.com  01-06-2020  100000
# 7     8    Grace          55    grace@example.com  01-07-2020  100000
# 8  nine    Heidi          60    heidi@example.com  2020.08.01  120000
# 9    10      Bob          65       10@example.com  01-09-2020  130000

# %%
 unique_values = data['ID'].unique()
 unique_values
# Out:
# array(['1', '2', '4', '5', '6', '7', '8', 'nine', '10'], dtype=object)

# %%
data.replace(8,9,inplace=True)
data.ID
# Out:
# 0       1
# 1       2
# 2       2
# 3       4
# 4       5
# 5       6
# 6       7
# 7       8
# 8    nine
# 9      10
# Name: ID, dtype: object

# %%
data
# Out:
#    ID     Name  Age                Email    JoinDate  Salary
# 0   1    Alice   25    alice@example.com  01-01-2020   50000
# 1   2      Bob   30      bob@example.com  not a date   60000
# 2   2      Bob   30      bob@example.com  01-02-2020   60000
# 3   4  Charlie  NaN  charlie@example.com  01-03-2020   70000
# 4   5    David   22                  NaN  01-04-2020   86666
# 5   6      Eve   45          eve@example  01-05-2020   90000
# 6   7    Frank   50   frank@@example.com  01-06-2020  100000
# 7   8    Grace   55    grace@example.com  01-07-2020  100000
# 8   9    Heidi   60    heidi@example.com  2020.08.01  120000
# 9  10      Bob   65       10@example.com  01-09-2020  130000

# %%
data.loc[data['ID'] == 'nine' , 'ID'] = 9

# %%
data.loc[data['Age'] == 'Twenty-two','Age'] = 22

# %%
data["Age"].replace(22, 23, inplace=True)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_5524\3193019340.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data["Age"].replace(22, 23, inplace=True)

# %%
data
# Out:
#    ID     Name  Age                Email    JoinDate  Salary
# 0   1    Alice   25    alice@example.com  01-01-2020   50000
# 1   2      Bob   30      bob@example.com  not a date   60000
# 2   2      Bob   30      bob@example.com  01-02-2020   60000
# 3   4  Charlie  NaN  charlie@example.com  01-03-2020   70000
# 4   5    David   23                  NaN  01-04-2020   86666
# 5   6      Eve   45          eve@example  01-05-2020   90000
# 6   7    Frank   50   frank@@example.com  01-06-2020  100000
# 7   8    Grace   55    grace@example.com  01-07-2020  100000
# 8   9    Heidi   60    heidi@example.com  2020.08.01  120000
# 9  10      Bob   65       10@example.com  01-09-2020  130000

# %%
data.dtypes
# Out:
# ID          object
# Name        object
# Age         object
# Email       object
# JoinDate    object
# Salary       int32
# dtype: object

# %%
from sklearn.impute import SimpleImputer

# %%
imputer = SimpleImputer(strategy = 'mean')
imputer.fit(data[['Age']])
data[['Age']] = imputer.transform(data[['Age']])

# %%
 data['ID'] = data['ID'].astype(int)

# %%
 data['Age'] = data['Age'].astype(int)

# %%
data
# Out:
#    ID     Name  Age                Email    JoinDate  Salary
# 0   1    Alice   25    alice@example.com  01-01-2020   50000
# 1   2      Bob   30      bob@example.com  not a date   60000
# 2   2      Bob   30      bob@example.com  01-02-2020   60000
# 3   4  Charlie   42  charlie@example.com  01-03-2020   70000
# 4   5    David   23                  NaN  01-04-2020   86666
# 5   6      Eve   45          eve@example  01-05-2020   90000
# 6   7    Frank   50   frank@@example.com  01-06-2020  100000
# 7   8    Grace   55    grace@example.com  01-07-2020  100000
# 8   9    Heidi   60    heidi@example.com  2020.08.01  120000
# 9  10      Bob   65       10@example.com  01-09-2020  130000

# %%
imputer = SimpleImputer(strategy = 'most_frequent')
imputer.fit(data[['Email']])
data[['Email']] = imputer.transform(data[['Email']])

# %%
data
# Out:
#    ID     Name  Age                Email    JoinDate  Salary
# 0   1    Alice   25    alice@example.com  01-01-2020   50000
# 1   2      Bob   30      bob@example.com  not a date   60000
# 2   2      Bob   30      bob@example.com  01-02-2020   60000
# 3   4  Charlie   42  charlie@example.com  01-03-2020   70000
# 4   5    David   23      bob@example.com  01-04-2020   86666
# 5   6      Eve   45          eve@example  01-05-2020   90000
# 6   7    Frank   50   frank@@example.com  01-06-2020  100000
# 7   8    Grace   55    grace@example.com  01-07-2020  100000
# 8   9    Heidi   60    heidi@example.com  2020.08.01  120000
# 9  10      Bob   65       10@example.com  01-09-2020  130000
